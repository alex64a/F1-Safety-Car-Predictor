# %% [markdown]
# # F1 Safety Car Predictor

# %% [markdown]
# ## Authors: Petar Stamenković, Aleksa Mitrovčan

# %% [markdown]
# ## Import new table with weather track data.

# %%
import pandas as pd
safety_car_predictor = pd.read_csv("safety_car_predictor.csv")
safety_car_predictor_shrinked = pd.read_csv("safety_car_predictor_shrinked.csv")
circuit_data = pd.read_csv("circuit_data.csv")
safety_car_predictor_shrinked
circuit_data
#safety_car_predictor
# Out:
#                          name  circuit_id circuit_type  phy_diff
# 0       Australian Grand Prix           1       street         2
# 1        Malaysian Grand Prix           2  traditional         4
# 2          Bahrain Grand Prix           3  traditional         3
# 3          Spanish Grand Prix           4  traditional         2
# 4          Turkish Grand Prix           5  traditional         2
# 5           Monaco Grand Prix           6       street         3
# 6         Canadian Grand Prix           7  traditional         2
# 7           French Grand Prix           8  traditional         2
# 8          British Grand Prix           9  traditional         1
# 9           German Grand Prix          10  traditional         2
# 10       Hungarian Grand Prix          11  traditional         2
# 11        European Grand Prix          12       street         2
# 12         Belgian Grand Prix          13  traditional         2
# 13         Italian Grand Prix          14  traditional         2
# 14       Singapore Grand Prix          15       street         4
# 15        Japanese Grand Prix          16  traditional         2
# 16         Chinese Grand Prix          17  traditional         2
# 17       Brazilian Grand Prix          18  traditional         2
# 18       Abu Dhabi Grand Prix          19  traditional         3
# 19          Korean Grand Prix          20  traditional         1
# 20          Indian Grand Prix          21  traditional         2
# 21   United States Grand Prix          22  traditional         2
# 22        Austrian Grand Prix          23  traditional         2
# 23         Russian Grand Prix          24       street         2
# 24         Mexican Grand Prix          25  traditional         3
# 25      Azerbaijan Grand Prix          26       street         3
# 26          Tuscan Grand Prix          27  traditional         2
# 27           Eifel Grand Prix          28  traditional         2
# 28       Portugese Grand Prix          29  traditional         2
# 29  Emilia Romagna Grand Prix          30  traditional         2
# 30           Qatar Grand Prix          31       street         4
# 31           Dutch Grand Prix          32  traditional         2
# 32   Saudi Arabian Grand Prix          33       street         3
# 33           Miami Grand Prix          34       street         3
# 34       Las Vegas Grand Prix          35       street         3

# %% [markdown]
# ## An attempt to use a shrinked table as fact-table. Merge two tables

# %%
#merged_table = safety_car_predictor_shrinked.join(circuit_data, on='name')
merged_table = pd.merge(safety_car_predictor_shrinked,circuit_data, on='name')
merged_table
# Out:
#      year                      name        date weather  num_dnfs  safety_car  \
# 0    2008     Australian Grand Prix   3/16/2008     dry        14        True
# 1    2008      Malaysian Grand Prix   4/23/2008     dry         5       False
# 2    2008        Bahrain Grand Prix    4/6/2008     dry         3       False
# 3    2008        Spanish Grand Prix   4/27/2008     dry         9        True
# 4    2008        Turkish Grand Prix   5/11/2008     dry         3        True
# ..    ...                       ...         ...     ...       ...         ...
# 322  2024      Singapore Grand Prix   9/22/2024     dry         2       False
# 323  2024  United States Grand Prix  10/20/2024     dry         1        True
# 324  2024      Las Vegas Grand Prix  11/23/2024     dry         2       False
# 325  2024          Qatar Grand Prix   12/1/2024     dry         5        True
# 326  2024      Abu Dhabi Grand Prix   12/8/2024     dry         4        True
#
#      circuit_id circuit_type  phy_diff
# 0             1       street         2
# 1             2  traditional         4
# 2             3  traditional         3
# 3             4  traditional         2
# 4             5  traditional         2
# ..          ...          ...       ...
# 322          15       street         4
# 323          22  traditional         2
# 324          35       street         3
# 325          31       street         4
# 326          19  traditional         3
#
# [327 rows x 9 columns]

# %% [markdown]
# ## Unique list of all circuits

# %%
safety_car_predictor.name.unique() # List out all circuits in order to create a new DataFrame for circuit ID
# Out:
# array(['Australian Grand Prix', 'Malaysian Grand Prix',
#        'Bahrain Grand Prix', 'Spanish Grand Prix', 'Turkish Grand Prix',
#        'Monaco Grand Prix', 'Canadian Grand Prix', 'French Grand Prix',
#        'British Grand Prix', 'German Grand Prix', 'Hungarian Grand Prix',
#        'European Grand Prix', 'Belgian Grand Prix', 'Italian Grand Prix',
#        'Singapore Grand Prix', 'Japanese Grand Prix',
#        'Chinese Grand Prix', 'Brazilian Grand Prix',
#        'Abu Dhabi Grand Prix', 'Korean Grand Prix', 'Indian Grand Prix ',
#        'United States Grand Prix', 'Austrian Grand Prix',
#        'Russian Grand Prix', 'Mexican Grand Prix',
#        'Azerbaijan Grand Prix', 'Tuscan Grand Prix', 'Eifel Grand Prix',
#        'Portuguese Grand Prix', 'Emilia Romagna Grand Prix',
#        'Qatar Grand Prix', 'Dutch Grand Prix', 'Mexico City Grand Prix',
#        'Sao Paulo Grand Prix', 'Saudi Arabian Grand Prix',
#        'Miami Grand Prix', 'Las Vegas Grand Prix'], dtype=object)

# %% [markdown]
# ## Creating a new DataFrame for mapping circuitID and safety car predictor table

# %%
circuit_mapping = {
    'Australian Grand Prix': 1,
    'Malaysian Grand Prix': 2,
    'Chinese Grand Prix': 3,
    'Bahrain Grand Prix': 4,
    'Spanish Grand Prix': 5,
    'Monaco Grand Prix': 6,
    'Canadian Grand Prix': 7,
    'British Grand Prix': 8,
    'German Grand Prix': 9,
    'Hungarian Grand Prix': 10,
    'Belgian Grand Prix': 11,
    'Italian Grand Prix': 12,
    'Singapore Grand Prix': 13,
    'Korean Grand Prix': 14,
    'Japanese Grand Prix': 15,
    'Indian Grand Prix': 16,
    'Abu Dhabi Grand Prix': 17,
    'United States Grand Prix': 18,
    'Brazilian Grand Prix': 19,
    'Austrian Grand Prix': 20,
    'Russian Grand Prix': 21,
    'Mexican Grand Prix': 22,
    'Azerbaijan Grand Prix': 23,
    'French Grand Prix': 24,
    'Tuscan Grand Prix': 25,
    'Eifel Grand Prix': 26,
    'Portuguese Grand Prix': 27,
    'Emilia Romagna Grand Prix': 28,
    'Turkish Grand Prix': 29,
    'Qatar Grand Prix': 30,
    'Dutch Grand Prix': 31,
    'Mexico City Grand Prix': 32,
    'Sao Paulo Grand Prix': 33,
    'Saudi Arabian Grand Prix': 34,
    'Miami Grand Prix': 35,
    'Las Vegas Grand Prix': 36
}

#safety_car_predictor.insert(0, 'circuit_id', safety_car_predictor['name'].map(circuit_mapping))
safety_car_predictor
# Out:
#      year                    name        date     weather  num_dnfs  \
# 0    2008   Australian Grand Prix   3/16/2008         dry        14
# 1    2008    Malaysian Grand Prix   4/23/2008         dry         5
# 2    2008      Bahrain Grand Prix    4/6/2008         dry         3
# 3    2008      Spanish Grand Prix   4/27/2008         dry         9
# 4    2008      Turkish Grand Prix   5/11/2008         dry         3
# ..    ...                     ...         ...         ...       ...
# 335  2024  Mexico City Grand Prix  10/27/2024         dry         3
# 336  2024    Sao Paulo Grand Prix   11/3/2024  heavy_rain         5
# 337  2024    Las Vegas Grand Prix  11/23/2024         dry         2
# 338  2024        Qatar Grand Prix   12/1/2024         dry         5
# 339  2024    Abu Dhabi Grand Prix   12/8/2024         dry         4
#
#     circuit_type  phy_diff  safety_car
# 0         street         2        True
# 1    traditional         4       False
# 2    traditional         3       False
# 3    traditional         2        True
# 4    traditional         2        True
# ..           ...       ...         ...
# 335  traditional         3        True
# 336  traditional         2        True
# 337       street         3       False
# 338       street         4        True
# 339  traditional         3        True
#
# [340 rows x 8 columns]

# %% [markdown]
# ## Calculate average number of dnfs for each circuit and create a separate column

# %%
safety_car_predictor['avg_dnfs_per_circuit'] = safety_car_predictor.groupby('name')['num_dnfs'].transform('mean')
safety_car_predictor
# Out:
#      year                    name        date     weather  num_dnfs  \
# 0    2008   Australian Grand Prix   3/16/2008         dry        14
# 1    2008    Malaysian Grand Prix   4/23/2008         dry         5
# 2    2008      Bahrain Grand Prix    4/6/2008         dry         3
# 3    2008      Spanish Grand Prix   4/27/2008         dry         9
# 4    2008      Turkish Grand Prix   5/11/2008         dry         3
# ..    ...                     ...         ...         ...       ...
# 335  2024  Mexico City Grand Prix  10/27/2024         dry         3
# 336  2024    Sao Paulo Grand Prix   11/3/2024  heavy_rain         5
# 337  2024    Las Vegas Grand Prix  11/23/2024         dry         2
# 338  2024        Qatar Grand Prix   12/1/2024         dry         5
# 339  2024    Abu Dhabi Grand Prix   12/8/2024         dry         4
#
#     circuit_type  phy_diff  safety_car  avg_dnfs_per_circuit
# 0         street         2        True              6.400000
# 1    traditional         4       False              5.100000
# 2    traditional         3       False              3.352941
# 3    traditional         2        True              3.352941
# 4    traditional         2        True              2.666667
# ..           ...       ...         ...                   ...
# 335  traditional         3        True              2.750000
# 336  traditional         2        True              4.000000
# 337       street         3       False              2.500000
# 338       street         4        True              3.000000
# 339  traditional         3        True              2.937500
#
# [340 rows x 9 columns]

# %% [markdown]
# ## Data modification for

# %%
# query_name = "Australian Grand Prix"
# safety_car_predictor_circuit = safety_car_predictor.loc[safety_car_predictor.name == query_name].copy()

# Replace string values in the 'weather' column
safety_car_predictor['weather'] = safety_car_predictor['weather'].replace({
    "dry": 0,
    "light_rain": 1,
    "heavy_rain": 2
})

# Replace string values in the 'circuit type' column
safety_car_predictor['circuit_type'] = safety_car_predictor['circuit_type'].replace({
    "traditional" : 0,
    "street" : 1
})

safety_car_predictor
# Out:
# C:\Users\Pera\AppData\Local\Temp\ipykernel_4700\3789583027.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   safety_car_predictor['weather'] = safety_car_predictor['weather'].replace({
# C:\Users\Pera\AppData\Local\Temp\ipykernel_4700\3789583027.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   safety_car_predictor['circuit_type'] = safety_car_predictor['circuit_type'].replace({
#      year                    name        date  weather  num_dnfs  \
# 0    2008   Australian Grand Prix   3/16/2008        0        14
# 1    2008    Malaysian Grand Prix   4/23/2008        0         5
# 2    2008      Bahrain Grand Prix    4/6/2008        0         3
# 3    2008      Spanish Grand Prix   4/27/2008        0         9
# 4    2008      Turkish Grand Prix   5/11/2008        0         3
# ..    ...                     ...         ...      ...       ...
# 335  2024  Mexico City Grand Prix  10/27/2024        0         3
# 336  2024    Sao Paulo Grand Prix   11/3/2024        2         5
# 337  2024    Las Vegas Grand Prix  11/23/2024        0         2
# 338  2024        Qatar Grand Prix   12/1/2024        0         5
# 339  2024    Abu Dhabi Grand Prix   12/8/2024        0         4
#
#      circuit_type  phy_diff  safety_car  avg_dnfs_per_circuit
# 0               1         2        True              6.400000
# 1               0         4       False              5.100000
# 2               0         3       False              3.352941
# 3               0         2        True              3.352941
# 4               0         2        True              2.666667
# ..            ...       ...         ...                   ...
# 335             0         3        True              2.750000
# 336             0         2        True              4.000000
# 337             1         3       False              2.500000
# 338             1         4        True              3.000000
# 339             0         3        True              2.937500
#
# [340 rows x 9 columns]

# %% [markdown]
# ## Random forrest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

features = ['weather', 'circuit_type', 'phy_diff','circuit_id','avg_dnfs_per_circuit']
X = safety_car_predictor[features]
y = safety_car_predictor.safety_car

train_X, val_x, train_y, val_y = train_test_split(X,y,random_state = 0)

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)

# Prediction sample has to be a 2-dimensional array [x,y,z]!
# x is a weather parameter and it maps to : 0 - dry , 1 - light rain , 2 - heavy rain
# y is a type of circuit parameter and it maps to : 0 - traditional , 1 - street
# z is a physical difficulty of circuit parameter and it has 4 levels

prediction_sample = [[1,1,2,1,5.857]] # For instance this predicts a safety car chance for Australian Grand Prix with light rain!
safety_car_deployment_prediction = forest_model.predict(prediction_sample) * 100


print(f"Prediction : {safety_car_deployment_prediction}%")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       2 from sklearn.model_selection import train_test_split
#       4 features = ['weather', 'circuit_type', 'phy_diff','circuit_id','avg_dnfs_per_circuit']
# ----> 5 X = safety_car_predictor[features]
#       6 y = safety_car_predictor.safety_car
#       8 train_X, val_x, train_y, val_y = train_test_split(X,y,random_state = 0)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['circuit_id'] not in index"

# %%
print(safety_car_predictor.groupby('weather')['safety_car'].mean()) # This shows what is the effect of a weather on a target variable

# %%
for column in range(len(features)):
    print(features[column], forest_model.feature_importances_[column]) # This command shows how important each column is for our model

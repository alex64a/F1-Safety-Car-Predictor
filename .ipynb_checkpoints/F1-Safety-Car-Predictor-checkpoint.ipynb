# %% [markdown]
# # F1 Safety Car Predictor

# %% [markdown]
# ## Authors: Petar Stamenković, Aleksa Mitrovčan

# %% [markdown]
# ## Import new table with weather track data.

# %%
safety_car_predictor = pd.read_csv("safety_car_predictor.csv")

#safety_car_predictor

# %% [markdown]
# ## Creating a new DataFrame for mapping circuitID and safety car predictor table

# %%
safety_car_predictor.name.unique() # List out all circuits in order to create a new DataFrame for circuit ID
circuit_mapping = {
    'Australian Grand Prix': 1,
    'Malaysian Grand Prix': 2,
    'Chinese Grand Prix': 3,
    'Bahrain Grand Prix': 4,
    'Spanish Grand Prix': 5,
    'Monaco Grand Prix': 6,
    'Canadian Grand Prix': 7,
    'British Grand Prix': 8,
    'German Grand Prix': 9,
    'Hungarian Grand Prix': 10,
    'Belgian Grand Prix': 11,
    'Italian Grand Prix': 12,
    'Singapore Grand Prix': 13,
    'Korean Grand Prix': 14,
    'Japanese Grand Prix': 15,
    'Indian Grand Prix': 16,
    'Abu Dhabi Grand Prix': 17,
    'United States Grand Prix': 18,
    'Brazilian Grand Prix': 19,
    'Austrian Grand Prix': 20,
    'Russian Grand Prix': 21,
    'Mexican Grand Prix': 22,
    'Azerbaijan Grand Prix': 23,
    'French Grand Prix': 24,
    'Tuscan Grand Prix': 25,
    'Eifel Grand Prix': 26,
    'Portuguese Grand Prix': 27,
    'Emilia Romagna Grand Prix': 28,
    'Turkish Grand Prix': 29,
    'Qatar Grand Prix': 30,
    'Dutch Grand Prix': 31,
    'Mexico City Grand Prix': 32,
    'Sao Paulo Grand Prix': 33,
    'Saudi Arabian Grand Prix': 34,
    'Miami Grand Prix': 35,
    'Las Vegas Grand Prix': 36
}

safety_car_predictor['circuit_id'] = safety_car_predictor['name'].map(circuit_mapping)
safety_car_predictor
# Out:
#      year                    name        date     weather  num_dnfs  \
# 0    2013   Australian Grand Prix   3/17/2013         dry         4
# 1    2013    Malaysian Grand Prix   3/24/2013  light_rain         6
# 2    2013      Chinese Grand Prix   4/14/2013         dry         4
# 3    2013      Bahrain Grand Prix   4/21/2013         dry         1
# 4    2013      Spanish Grand Prix   5/12/2013         dry         3
# ..    ...                     ...         ...         ...       ...
# 242  2024  Mexico City Grand Prix  10/27/2024         dry         3
# 243  2024    Sao Paulo Grand Prix   11/3/2024  heavy_rain         5
# 244  2024    Las Vegas Grand Prix  11/23/2024         dry         2
# 245  2024        Qatar Grand Prix   12/1/2024         dry         5
# 246  2024    Abu Dhabi Grand Prix   12/8/2024         dry         4
#
#     circuit_type  phy_diff  safety_car  circuit_id
# 0         street         2       False         1.0
# 1    traditional         4       False         2.0
# 2    traditional         2       False         3.0
# 3    traditional         3       False         4.0
# 4    traditional         2       False         5.0
# ..           ...       ...         ...         ...
# 242  traditional         3        True        32.0
# 243  traditional         2        True        33.0
# 244       street         3       False        36.0
# 245       street         4        True        30.0
# 246  traditional         3        True        17.0
#
# [247 rows x 9 columns]

# %% [markdown]
# ## Calculate average number of dnfs for each circuit and create a separate column

# %%
safety_car_predictor['avg_dnfs_per_circuit'] = safety_car_predictor.groupby('name')['num_dnfs'].transform('mean')
safety_car_predictor
# Out:
#      year                    name        date     weather  num_dnfs  \
# 0    2013   Australian Grand Prix   3/17/2013         dry         4
# 1    2013    Malaysian Grand Prix   3/24/2013  light_rain         6
# 2    2013      Chinese Grand Prix   4/14/2013         dry         4
# 3    2013      Bahrain Grand Prix   4/21/2013         dry         1
# 4    2013      Spanish Grand Prix   5/12/2013         dry         3
# ..    ...                     ...         ...         ...       ...
# 242  2024  Mexico City Grand Prix  10/27/2024         dry         3
# 243  2024    Sao Paulo Grand Prix   11/3/2024  heavy_rain         5
# 244  2024    Las Vegas Grand Prix  11/23/2024         dry         2
# 245  2024        Qatar Grand Prix   12/1/2024         dry         5
# 246  2024    Abu Dhabi Grand Prix   12/8/2024         dry         4
#
#     circuit_type  phy_diff  safety_car  circuit_id  avg_dnfs_per_circuit
# 0         street         2       False         1.0              4.900000
# 1    traditional         4       False         2.0              4.600000
# 2    traditional         2       False         3.0              2.750000
# 3    traditional         3       False         4.0              3.076923
# 4    traditional         2       False         5.0              2.250000
# ..           ...       ...         ...         ...                   ...
# 242  traditional         3        True        32.0              2.750000
# 243  traditional         2        True        33.0              4.000000
# 244       street         3       False        36.0              2.500000
# 245       street         4        True        30.0              3.000000
# 246  traditional         3        True        17.0              2.500000
#
# [247 rows x 10 columns]

# %% [markdown]
# ## Data modification for

# %%
# query_name = "Australian Grand Prix"
# safety_car_predictor_circuit = safety_car_predictor.loc[safety_car_predictor.name == query_name].copy()

# Replace string values in the 'weather' column
safety_car_predictor['weather'] = safety_car_predictor['weather'].replace({
    "dry": 0,
    "light_rain": 1,
    "heavy_rain": 2
})

# Replace string values in the 'circuit type' column
safety_car_predictor['circuit_type'] = safety_car_predictor['circuit_type'].replace({
    "traditional" : 0,
    "street" : 1
})

safety_car_predictor
# Out:
# C:\Users\Pera\AppData\Local\Temp\ipykernel_5684\943355734.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   safety_car_predictor['weather'] = safety_car_predictor['weather'].replace({
# C:\Users\Pera\AppData\Local\Temp\ipykernel_5684\943355734.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   safety_car_predictor['circuit_type'] = safety_car_predictor['circuit_type'].replace({
#      year                    name        date  weather  num_dnfs  \
# 0    2013   Australian Grand Prix   3/17/2013        0         4
# 1    2013    Malaysian Grand Prix   3/24/2013        1         6
# 2    2013      Chinese Grand Prix   4/14/2013        0         4
# 3    2013      Bahrain Grand Prix   4/21/2013        0         1
# 4    2013      Spanish Grand Prix   5/12/2013        0         3
# ..    ...                     ...         ...      ...       ...
# 242  2024  Mexico City Grand Prix  10/27/2024        0         3
# 243  2024    Sao Paulo Grand Prix   11/3/2024        2         5
# 244  2024    Las Vegas Grand Prix  11/23/2024        0         2
# 245  2024        Qatar Grand Prix   12/1/2024        0         5
# 246  2024    Abu Dhabi Grand Prix   12/8/2024        0         4
#
#      circuit_type  phy_diff  safety_car  circuit_id  avg_dnfs_per_circuit
# 0               1         2       False         1.0              4.900000
# 1               0         4       False         2.0              4.600000
# 2               0         2       False         3.0              2.750000
# 3               0         3       False         4.0              3.076923
# 4               0         2       False         5.0              2.250000
# ..            ...       ...         ...         ...                   ...
# 242             0         3        True        32.0              2.750000
# 243             0         2        True        33.0              4.000000
# 244             1         3       False        36.0              2.500000
# 245             1         4        True        30.0              3.000000
# 246             0         3        True        17.0              2.500000
#
# [247 rows x 10 columns]

# %% [markdown]
# ## Random forrest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

features = ['weather', 'circuit_type', 'phy_diff','circuit_id','avg_dnfs_per_circuit']
X = safety_car_predictor[features]
y = safety_car_predictor.safety_car

train_X,val_x, train_y, val_y = train_test_split(X,y,random_state = 0)

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)

# Prediction sample has to be a 2-dimensional array [x,y,z]!
# x is a weather parameter and it maps to : 0 - dry , 1 - light rain , 2 - heavy rain
# y is a type of circuit parameter and it maps to : 0 - traditional , 1 - street
# z is a physical difficulty of circuit parameter and it has 4 levels

prediction_sample = [[1,1,2,1,4.9]] # For instance this predicts a safety car chance for Australian Grand Prix with light rain!
safety_car_deployment_prediction = forest_model.predict(prediction_sample) * 100


print(f"Prediction : {safety_car_deployment_prediction}%")
# Out:
# Prediction : [75.71062549]%
# C:\Users\Pera\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
print(safety_car_predictor.groupby('weather')['safety_car'].mean()) # This shows what is the effect of a weather on a target variable
# Out:
# weather
# 0    0.665138
# 1    0.714286
# 2    0.875000
# Name: safety_car, dtype: float64

# %%
print(forest_model.feature_importances_) # This command shows how important each column is for our model
# Out:
# [0.17392922 0.03214026 0.08193707 0.37134144 0.340652  ]

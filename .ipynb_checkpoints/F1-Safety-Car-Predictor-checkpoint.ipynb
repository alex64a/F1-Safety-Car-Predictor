# %% [markdown]
# # F1 Safety Car Predictor

# %% [markdown]
# ## Authors: Petar Stamenković, Aleksa Mitrovčan

# %% [markdown]
# ## Import new table with weather track data.

# %%
import numpy as np
import pandas as pd
safety_car_predictor = pd.read_csv("safety_car_predictor.csv")
circuit_data = pd.read_csv("circuit_data.csv")
safety_car_predictor
circuit_data
#safety_car_predictor
# Out:
#                          name  circuit_id circuit_type  phy_diff
# 0       Australian Grand Prix           1       street         2
# 1        Malaysian Grand Prix           2  traditional         4
# 2          Bahrain Grand Prix           3  traditional         3
# 3          Spanish Grand Prix           4  traditional         2
# 4          Turkish Grand Prix           5  traditional         2
# 5           Monaco Grand Prix           6       street         3
# 6         Canadian Grand Prix           7  traditional         2
# 7           French Grand Prix           8  traditional         2
# 8          British Grand Prix           9  traditional         1
# 9           German Grand Prix          10  traditional         2
# 10       Hungarian Grand Prix          11  traditional         2
# 11        European Grand Prix          12       street         2
# 12         Belgian Grand Prix          13  traditional         2
# 13         Italian Grand Prix          14  traditional         2
# 14       Singapore Grand Prix          15       street         4
# 15        Japanese Grand Prix          16  traditional         2
# 16         Chinese Grand Prix          17  traditional         2
# 17       Brazilian Grand Prix          18  traditional         2
# 18       Abu Dhabi Grand Prix          19  traditional         3
# 19          Korean Grand Prix          20  traditional         1
# 20          Indian Grand Prix          21  traditional         2
# 21   United States Grand Prix          22  traditional         2
# 22        Austrian Grand Prix          23  traditional         2
# 23         Russian Grand Prix          24       street         2
# 24         Mexican Grand Prix          25  traditional         3
# 25      Azerbaijan Grand Prix          26       street         3
# 26          Tuscan Grand Prix          27  traditional         2
# 27           Eifel Grand Prix          28  traditional         2
# 28       Portugese Grand Prix          29  traditional         2
# 29  Emilia Romagna Grand Prix          30  traditional         2
# 30           Qatar Grand Prix          31       street         4
# 31           Dutch Grand Prix          32  traditional         2
# 32   Saudi Arabian Grand Prix          33       street         3
# 33           Miami Grand Prix          34       street         3
# 34       Las Vegas Grand Prix          35       street         3
# 35    Indianapolis Grand Prix          36  traditional         1
# 36       Argentina Grand Prix          37  traditional         2

# %% [markdown]
# ## An attempt to use a shrinked table as fact-table. Merge two tables

# %%
#merged_table = safety_car_predictor_shrinked.join(circuit_data, on='name')
safety_car_predictor = pd.merge(safety_car_predictor,circuit_data, on='name')
safety_car_predictor
# Out:
#      year                       name        date     weather  num_dnfs  \
# 0    1997      Australian Grand Prix    3/9/1997         dry        13
# 1    1997       Brazilian Grand Prix   3/30/1997         dry         4
# 2    1997       Argentina Grand Prix   4/13/1997         dry        13
# 3    1997  Emilia Romagna Grand Prix   4/27/1997         dry        11
# 4    1997          Monaco Grand Prix   5/11/1997  heavy_rain        12
# ..    ...                        ...         ...         ...       ...
# 511  2024   United States Grand Prix  10/20/2024         dry         1
# 512  2024       Las Vegas Grand Prix  11/23/2024         dry         2
# 513  2024           Qatar Grand Prix   12/1/2024         dry         5
# 514  2024       Abu Dhabi Grand Prix   12/8/2024         dry         4
# 515  2025      Australian Grand Prix   3/16/2025  light_rain         6
#
#     safety_car  num_of_sc num_of_vsc  total  circuit_id circuit_type  phy_diff
# 0       FALSE         0.0        Nan      0           1       street         2
# 1       FALSE         0.0        Nan      0          18  traditional         2
# 2         TRUE        1.0        Nan      1          37  traditional         2
# 3       FALSE         0.0        Nan      0          30  traditional         2
# 4       FALSE         0.0        Nan      0           6       street         3
# ..         ...        ...        ...    ...         ...          ...       ...
# 511       TRUE        NaN        NaN      0          22  traditional         2
# 512      FALSE        NaN        NaN      0          35       street         3
# 513       TRUE        NaN        NaN      0          31       street         4
# 514       TRUE        NaN        NaN      0          19  traditional         3
# 515       TRUE        2.0          0      2           1       street         2
#
# [516 rows x 12 columns]

# %% [markdown]
# ## Unique list of all circuits

# %%
safety_car_predictor.name.unique() # List out all circuits in order to create a new DataFrame for circuit ID
# Out:
# array(['Australian Grand Prix', 'Brazilian Grand Prix',
#        'Argentina Grand Prix', 'Emilia Romagna Grand Prix',
#        'Monaco Grand Prix', 'Spanish Grand Prix', 'Canadian Grand Prix',
#        'French Grand Prix', 'British Grand Prix', 'German Grand Prix',
#        'Hungarian Grand Prix', 'Belgian Grand Prix', 'Italian Grand Prix',
#        'Austrian Grand Prix', 'European Grand Prix',
#        'Japanese Grand Prix', 'Malaysian Grand Prix',
#        'Indianapolis Grand Prix', 'Bahrain Grand Prix',
#        'Chinese Grand Prix', 'Turkish Grand Prix', 'Singapore Grand Prix',
#        'Abu Dhabi Grand Prix', 'Korean Grand Prix',
#        'United States Grand Prix', 'Russian Grand Prix',
#        'Mexican Grand Prix', 'Azerbaijan Grand Prix', 'Tuscan Grand Prix',
#        'Eifel Grand Prix', 'Qatar Grand Prix', 'Dutch Grand Prix',
#        'Saudi Arabian Grand Prix', 'Miami Grand Prix',
#        'Las Vegas Grand Prix'], dtype=object)

# %% [markdown]
# ## Creating a new DataFrame for mapping circuitID and safety car predictor table

# %%
circuit_mapping = {
    "Australian Grand Prix": 1,
    "Malaysian Grand Prix": 2,
    "Bahrain Grand Prix": 3,
    "Spanish Grand Prix": 4,
    "Turkish Grand Prix": 5,
    "Monaco Grand Prix": 6,
    "Canadian Grand Prix": 7,
    "French Grand Prix": 8,
    "British Grand Prix": 9,
    "German Grand Prix": 10,
    "Hungarian Grand Prix": 11,
    "European Grand Prix": 12,
    "Belgian Grand Prix": 13,
    "Italian Grand Prix": 14,
    "Singapore Grand Prix": 15,
    "Japanese Grand Prix": 16,
    "Chinese Grand Prix": 17,
    "Brazilian Grand Prix": 18,
    "Abu Dhabi Grand Prix": 19,
    "Korean Grand Prix": 20,
    "Indian Grand Prix": 21,
    "United States Grand Prix": 22,
    "Austrian Grand Prix": 23,
    "Russian Grand Prix": 24,
    "Mexican Grand Prix": 25,
    "Azerbaijan Grand Prix": 26,
    "Tuscan Grand Prix": 27,
    "Eifel Grand Prix": 28,
    "Portugese Grand Prix": 29,
    "Emilia Romagna Grand Prix": 30,
    "Qatar Grand Prix": 31,
    "Dutch Grand Prix": 32,
    "Saudi Arabian Grand Prix": 33,
    "Miami Grand Prix": 34,
    "Las Vegas Grand Prix": 35,
    "Indianapolis Grand Prix": 36,
    "Argentina Grand Prix": 37
}


#safety_car_predictor.insert(0, 'circuit_id', safety_car_predictor['name'].map(circuit_mapping))
safety_car_predictor
# Out:
#      year                       name        date     weather  num_dnfs  \
# 0    1997      Australian Grand Prix    3/9/1997         dry        13
# 1    1997       Brazilian Grand Prix   3/30/1997         dry         4
# 2    1997       Argentina Grand Prix   4/13/1997         dry        13
# 3    1997  Emilia Romagna Grand Prix   4/27/1997         dry        11
# 4    1997          Monaco Grand Prix   5/11/1997  heavy_rain        12
# ..    ...                        ...         ...         ...       ...
# 511  2024   United States Grand Prix  10/20/2024         dry         1
# 512  2024       Las Vegas Grand Prix  11/23/2024         dry         2
# 513  2024           Qatar Grand Prix   12/1/2024         dry         5
# 514  2024       Abu Dhabi Grand Prix   12/8/2024         dry         4
# 515  2025      Australian Grand Prix   3/16/2025  light_rain         6
#
#     safety_car  num_of_sc num_of_vsc  total  circuit_id circuit_type  phy_diff
# 0       FALSE         0.0        Nan      0           1       street         2
# 1       FALSE         0.0        Nan      0          18  traditional         2
# 2         TRUE        1.0        Nan      1          37  traditional         2
# 3       FALSE         0.0        Nan      0          30  traditional         2
# 4       FALSE         0.0        Nan      0           6       street         3
# ..         ...        ...        ...    ...         ...          ...       ...
# 511       TRUE        NaN        NaN      0          22  traditional         2
# 512      FALSE        NaN        NaN      0          35       street         3
# 513       TRUE        NaN        NaN      0          31       street         4
# 514       TRUE        NaN        NaN      0          19  traditional         3
# 515       TRUE        2.0          0      2           1       street         2
#
# [516 rows x 12 columns]

# %% [markdown]
# ## Calculate average number of dnfs for each circuit and create a separate column

# %%
safety_car_predictor['avg_dnfs_per_circuit'] = safety_car_predictor.groupby('name')['num_dnfs'].transform('mean')
safety_car_predictor
# Out:
#      year                       name        date     weather  num_dnfs  \
# 0    1997      Australian Grand Prix    3/9/1997         dry        13
# 1    1997       Brazilian Grand Prix   3/30/1997         dry         4
# 2    1997       Argentina Grand Prix   4/13/1997         dry        13
# 3    1997  Emilia Romagna Grand Prix   4/27/1997         dry        11
# 4    1997          Monaco Grand Prix   5/11/1997  heavy_rain        12
# ..    ...                        ...         ...         ...       ...
# 511  2024   United States Grand Prix  10/20/2024         dry         1
# 512  2024       Las Vegas Grand Prix  11/23/2024         dry         2
# 513  2024           Qatar Grand Prix   12/1/2024         dry         5
# 514  2024       Abu Dhabi Grand Prix   12/8/2024         dry         4
# 515  2025      Australian Grand Prix   3/16/2025  light_rain         6
#
#     safety_car  num_of_sc num_of_vsc  total  circuit_id circuit_type  \
# 0       FALSE         0.0        Nan      0           1       street
# 1       FALSE         0.0        Nan      0          18  traditional
# 2         TRUE        1.0        Nan      1          37  traditional
# 3       FALSE         0.0        Nan      0          30  traditional
# 4       FALSE         0.0        Nan      0           6       street
# ..         ...        ...        ...    ...         ...          ...
# 511       TRUE        NaN        NaN      0          22  traditional
# 512      FALSE        NaN        NaN      0          35       street
# 513       TRUE        NaN        NaN      0          31       street
# 514       TRUE        NaN        NaN      0          19  traditional
# 515       TRUE        2.0          0      2           1       street
#
#      phy_diff  avg_dnfs_per_circuit  avg_sc_per_circuit
# 0           2              7.703704            1.074074
# 1           2              5.695652            0.200000
# 2           2             10.500000            0.500000
# 3           2              7.071429            0.357143
# 4           3              6.925926            0.888889
# ..        ...                   ...                 ...
# 511         2              3.250000                 NaN
# 512         3              2.500000                 NaN
# 513         4              3.000000                 NaN
# 514         3              2.937500                 NaN
# 515         2              7.703704            1.074074
#
# [516 rows x 14 columns]

# %% [markdown]
# ## Calculate average number of safety cars and virtual safety cars per race

# %%
# Ignore the NaN values
safety_car_predictor['num_of_vsc'] = pd.to_numeric(safety_car_predictor['num_of_vsc'], errors='coerce')

safety_car_predictor['avg_sc_per_circuit'] = safety_car_predictor.groupby('name')['num_of_sc'].transform('mean')
safety_car_predictor['avg_vsc_per_circuit'] = safety_car_predictor.groupby('name')['num_of_vsc'].transform(lambda x:x.mean(skipna=True))
#rearange columns
columns = ['year', 'name', 'circuit_id', 'circuit_type', 'phy_diff', 'date', 'weather', 'num_dnfs', 'avg_dnfs_per_circuit', 'num_of_sc', 'num_of_vsc', 'total', 'avg_sc_per_circuit', 'avg_vsc_per_circuit', 
           'safety_car']
safety_car_predictor = safety_car_predictor[columns]
safety_car_predictor
# Out:
#      year                       name  circuit_id circuit_type  phy_diff  \
# 0    1997      Australian Grand Prix           1       street         2
# 1    1997       Brazilian Grand Prix          18  traditional         2
# 2    1997       Argentina Grand Prix          37  traditional         2
# 3    1997  Emilia Romagna Grand Prix          30  traditional         2
# 4    1997          Monaco Grand Prix           6       street         3
# ..    ...                        ...         ...          ...       ...
# 511  2024   United States Grand Prix          22  traditional         2
# 512  2024       Las Vegas Grand Prix          35       street         3
# 513  2024           Qatar Grand Prix          31       street         4
# 514  2024       Abu Dhabi Grand Prix          19  traditional         3
# 515  2025      Australian Grand Prix           1       street         2
#
#            date     weather  num_dnfs  avg_dnfs_per_circuit  num_of_sc  \
# 0      3/9/1997         dry        13              7.703704        0.0
# 1     3/30/1997         dry         4              5.695652        0.0
# 2     4/13/1997         dry        13             10.500000        1.0
# 3     4/27/1997         dry        11              7.071429        0.0
# 4     5/11/1997  heavy_rain        12              6.925926        0.0
# ..          ...         ...       ...                   ...        ...
# 511  10/20/2024         dry         1              3.250000        NaN
# 512  11/23/2024         dry         2              2.500000        NaN
# 513   12/1/2024         dry         5              3.000000        NaN
# 514   12/8/2024         dry         4              2.937500        NaN
# 515   3/16/2025  light_rain         6              7.703704        2.0
#
#      num_of_vsc  total  avg_sc_per_circuit  avg_vsc_per_circuit safety_car
# 0           NaN      0            1.074074             0.555556     FALSE
# 1           NaN      0            0.200000                  NaN     FALSE
# 2           NaN      1            0.500000                  NaN       TRUE
# 3           NaN      0            0.357143             0.250000     FALSE
# 4           NaN      0            0.888889             0.777778     FALSE
# ..          ...    ...                 ...                  ...        ...
# 511         NaN      0                 NaN                  NaN       TRUE
# 512         NaN      0                 NaN                  NaN      FALSE
# 513         NaN      0                 NaN                  NaN       TRUE
# 514         NaN      0                 NaN                  NaN       TRUE
# 515         0.0      2            1.074074             0.555556       TRUE
#
# [516 rows x 15 columns]

# %% [markdown]
# ## Data modification for model training

# %%
# safety_car_predictor_circuit = safety_car_predictor.loc[safety_car_predictor.name == query_name].copy()

# Replace string values in the 'weather' column
safety_car_predictor['weather'] = safety_car_predictor['weather'].replace({
    "dry": 0,
    "light_rain": 1,
    "heavy_rain": 2
})

# Replace string values in the 'circuit type' column
safety_car_predictor['circuit_type'] = safety_car_predictor['circuit_type'].replace({
    "traditional" : 0,
    "street" : 1
})

safety_car_predictor

# %% [markdown]
# ## Random forrest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
#columns = ['year', 'name', 'circuit_id', 'date', 'weather', 'num_dnfs', 'avg_dnfs_per_circuit', 'num_of_sc', 'num_of_vsc', 'total', 'avg_sc_per_circuit', 'avg_vsc_per_circuit', 
#           'safety_car']
circuit_names = ['Australian Grand Prix' , 'Argentina Grand Prix', 'Malaysian Grand Prix',
       'Brazilian Grand Prix', 'Emilia Romagna Grand Prix',
       'Spanish Grand Prix', 'Austrian Grand Prix', 'Monaco Grand Prix',
       'Canadian Grand Prix', 'European Grand Prix', 'British Grand Prix',
       'French Grand Prix', 'German Grand Prix', 'Hungarian Grand Prix',
       'Belgian Grand Prix', 'Italian Grand Prix',
       'Indianapolis Grand Prix', 'Japanese Grand Prix',
       'Bahrain Grand Prix', 'Chinese Grand Prix', 'Turkish Grand Prix',
       'Singapore Grand Prix', 'Abu Dhabi Grand Prix',
       'Korean Grand Prix', 'United States Grand Prix',
       'Russian Grand Prix', 'Mexican Grand Prix',
       'Azerbaijan Grand Prix', 'Tuscan Grand Prix', 'Eifel Grand Prix',
       'Qatar Grand Prix', 'Dutch Grand Prix', 'Saudi Arabian Grand Prix',
       'Miami Grand Prix', 'Las Vegas Grand Prix']
features = ['circuit_id', 'weather', 'circuit_type', 'phy_diff','avg_dnfs_per_circuit', 'avg_sc_per_circuit', 'avg_vsc_per_circuit']
X = safety_car_predictor[features]
y = safety_car_predictor.safety_car

train_X, val_x, train_y, val_y = train_test_split(X,y,random_state = 0)

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)

# Prediction sample has to be a 2-dimensional array [x,y,z]!
# x is a weather parameter and it maps to : 0 - dry , 1 - light rain , 2 - heavy rain
# y is a type of circuit parameter and it maps to : 0 - traditional , 1 - street
# z is a physical difficulty of circuit parameter and it has 4 levels

# Enter circuit name (ex. Australian Grand Prix) for the prediction
# Manually edit weather forecast (0 - dry, 1 - light rain, 2 - heavy rain)


while True:
    circuit_name = input("Enter circuit name (ex. Australian Grand Prix) for the prediction : ").strip()
    if circuit_name in circuit_names:
        print(f"Valid circuit: {circuit_name}")
        break
    else:
        print("Invalid circuit name! Please enter a valid Grand Prix name.")
        
while True:
    valid_weather=[0,1,2]
    weather = int(input("Enter weather forecast (0 - dry, 1 - light rain, 2 - heavy rain)"))
    if weather in valid_weather:
        print(f"Valid weather input: {weather}")
        break
    else:
        print("Invalid weather! Please enter a valid value.")
prediction_sample = safety_car_predictor[safety_car_predictor['name'] == circuit_name][['circuit_id', 'circuit_type', 'phy_diff','avg_dnfs_per_circuit','avg_sc_per_circuit', 'avg_vsc_per_circuit']]
prediction_sample = prediction_sample.iloc[0].tolist()
prediction_sample.insert(1, weather)
print(prediction_sample)

#prediction_sample = [[1,1,1,2,6.761905, 1.095238, 0.625000]] # For instance this predicts a safety car chance for Australian Grand Prix with light rain!
safety_car_deployment_prediction = forest_model.predict([prediction_sample]) * 100
safety_car_deployment_prediction_rounded = np.round(safety_car_deployment_prediction,2)


print('\033[92m' + '\033[1m' + f"Prediction : {safety_car_deployment_prediction_rounded}%")

# %%
print(safety_car_predictor.groupby('weather')['safety_car'].mean()) # This shows what is the effect of a weather on a target variable

# %%
for column in range(len(features)):
    print(features[column], forest_model.feature_importances_[column]) # This command shows how important each column is for our model
